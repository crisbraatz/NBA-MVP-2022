# %%
from google.colab import drive
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot
import numpy
import pandas
import seaborn
import warnings
warnings.filterwarnings('ignore')

# %%
drive.mount('/content/drive')
df = pandas.read_csv('/content/drive/MyDrive/df_nba_mvp_1980_2022.csv', sep = ',', decimal = '.')
# Out:
# Mounted at /content/drive

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20452 entries, 0 to 20451
# Data columns (total 56 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   20452 non-null  object
#  1   Pos      20452 non-null  object
#  2   Age      20452 non-null  int64
#  3   Tm       20452 non-null  object
#  4   G        20452 non-null  int64
#  5   GS       20452 non-null  int64
#  6   MP       20452 non-null  float64
#  7   FG       20452 non-null  float64
#  8   FGA      20452 non-null  float64
#  9   FG%      20452 non-null  float64
#  10  3P       20452 non-null  float64
#  11  3PA      20452 non-null  float64
#  12  3P%      20452 non-null  float64
#  13  2P       20452 non-null  float64
#  14  2PA      20452 non-null  float64
#  15  2P%      20452 non-null  float64
#  16  eFG%     20452 non-null  float64
#  17  FT       20452 non-null  float64
#  18  FTA      20452 non-null  float64
#  19  FT%      20452 non-null  float64
#  20  ORB      20452 non-null  float64
#  21  DRB      20452 non-null  float64
#  22  TRB      20452 non-null  float64
#  23  AST      20452 non-null  float64
#  24  STL      20452 non-null  float64
#  25  BLK      20452 non-null  float64
#  26  TOV      20452 non-null  float64
#  27  PF       20452 non-null  float64
#  28  PTS      20452 non-null  float64
#  29  Season   20452 non-null  int64
#  30  PER      20452 non-null  float64
#  31  TS%      20452 non-null  float64
#  32  3PAr     20452 non-null  float64
#  33  FTr      20452 non-null  float64
#  34  ORB%     20452 non-null  float64
#  35  DRB%     20452 non-null  float64
#  36  TRB%     20452 non-null  float64
#  37  AST%     20452 non-null  float64
#  38  STL%     20452 non-null  float64
#  39  BLK%     20452 non-null  float64
#  40  TOV%     20452 non-null  float64
#  41  USG%     20452 non-null  float64
#  42  OWS      20452 non-null  float64
#  43  DWS      20452 non-null  float64
#  44  WS       20452 non-null  float64
#  45  WS/48    20452 non-null  float64
#  46  OBPM     20452 non-null  float64
#  47  DBPM     20452 non-null  float64
#  48  BPM      20452 non-null  float64
#  49  VORP     20452 non-null  float64
#  50  First    20452 non-null  int64
#  51  Pts Won  20452 non-null  int64
#  52  Pts Max  20452 non-null  int64
#  53  Share    20452 non-null  float64
#  54  Rk       20452 non-null  int64
#  55  Overall  20452 non-null  object
# dtypes: float64(44), int64(8), object(4)
# memory usage: 8.7+ MB

# %%
df['Wins'] = df.Overall.apply(lambda x: x.split('-')[0]).astype(int)
df['Losses'] = df.Overall.apply(lambda x: x.split('-')[1]).astype(int)
df['W/L%'] = df.Wins / (df.Wins + df.Losses)
df['GS%'] = df.GS / df.G
df['GP%'] = df.G / (df.Wins + df.Losses)
df['MVP Rank'] = numpy.where(df.Season <= 2021, df.groupby('Season')['Pts Won'].rank(ascending = False, method = 'dense'), 0.0)
df['Won MVP'] = numpy.where(df['MVP Rank'] == 1, 1, 0)

# %%
df.tail()
# Out:
#                Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 20447  Thaddeus Young  PF   33  TOR  26   0  18.3  2.6   5.5  0.465  ...
# 20448      Trae Young  PG   23  ATL  76  76  34.9  9.4  20.3  0.460  ...
# 20449  Omer Yurtseven   C   23  MIA  56  12  12.6  2.3   4.4  0.526  ...
# 20450     Cody Zeller   C   29  POR  27   0  13.1  1.9   3.3  0.567  ...
# 20451     Ivica Zubac   C   24  LAC  76  76  24.4  4.1   6.5  0.626  ...
#
#        Share  Rk  Overall  Wins  Losses      W/L%       GS%       GP%  \
# 20447    0.0  11    48-34    48      34  0.585366  0.000000  0.317073
# 20448    0.0  16    43-39    43      39  0.524390  1.000000  0.926829
# 20449    0.0   4    53-29    53      29  0.646341  0.214286  0.682927
# 20450    0.0  25    27-55    27      55  0.329268  0.000000  0.329268
# 20451    0.0  18    42-40    42      40  0.512195  1.000000  0.926829
#
#        MVP Rank  Won MVP
# 20447       0.0        0
# 20448       0.0        0
# 20449       0.0        0
# 20450       0.0        0
# 20451       0.0        0
#
# [5 rows x 63 columns]

# %%
df_past = df[df.Season <= 2021]
df_current = df[df.Season == 2022]

# %%
corr = df_past.corr(method = 'pearson')
won_mvp_corr = corr[['Won MVP']]
won_mvp_corr['Won MVP'].abs().sort_values()
# Out:
# ORB%        0.003019
# Season      0.008010
# 3PAr        0.008282
# TOV%        0.012399
# Age         0.012932
# BLK%        0.014322
# 3P%         0.017630
# FTr         0.019449
# STL%        0.020630
# PF          0.025236
# FT%         0.026412
# TRB%        0.028929
# eFG%        0.029560
# 2P%         0.030289
# FG%         0.031790
# DRB%        0.037830
# TS%         0.038824
# 3PA         0.040807
# 3P          0.042739
# OBPM        0.048505
# G           0.049953
# GP%         0.050274
# DBPM        0.051898
# ORB         0.055596
# BPM         0.056663
# BLK         0.067703
# GS%         0.069953
# Rk          0.071064
# Losses      0.072923
# Wins        0.073705
# W/L%        0.075250
# AST%        0.076802
# MP          0.078541
# WS/48       0.083676
# GS          0.085562
# STL         0.087134
# USG%        0.094374
# TRB         0.095040
# DRB         0.107542
# AST         0.108231
# PER         0.108443
# TOV         0.111194
# 2PA         0.121143
# FGA         0.121554
# 2P          0.133474
# FG          0.135357
# PTS         0.142151
# DWS         0.148060
# FTA         0.149411
# FT          0.155038
# MVP Rank    0.200514
# WS          0.209616
# OWS         0.216693
# Pts Max     0.242914
# VORP        0.260419
# Pts Won     0.702176
# Share       0.724682
# First       0.901634
# Won MVP     1.000000
# Name: Won MVP, dtype: float64

# %%
df_past.Player.count()
# Out:
# 19737

# %%
df_past = df_past[df_past['Pts Won'] > 0]
df_past.Player.count()
# Out:
# 678

# %%
corr = df_past.corr(method = 'pearson')
won_mvp_corr = corr[['Won MVP']]
won_mvp_corr['Won MVP'].abs().sort_values()
# Out:
# ORB%        0.006550
# Pts Max     0.018274
# ORB         0.018825
# Age         0.026243
# BLK%        0.032685
# FTr         0.035047
# 3PAr        0.038524
# Season      0.039996
# TOV%        0.041757
# 3P%         0.043152
# GS%         0.045903
# BLK         0.048593
# STL%        0.049670
# 3PA         0.063831
# STL         0.064766
# 3P          0.071655
# TRB%        0.077006
# GS          0.078323
# G           0.081707
# FG%         0.085074
# FT%         0.090131
# DRB%        0.094352
# PF          0.098983
# TRB         0.100283
# MP          0.100432
# GP%         0.101369
# AST         0.107378
# 2P%         0.117987
# eFG%        0.125028
# AST%        0.125577
# DRB         0.130452
# 2PA         0.134002
# TOV         0.136487
# TS%         0.159624
# FTA         0.163575
# 2P          0.170933
# FGA         0.175530
# FT          0.190702
# USG%        0.192139
# DBPM        0.205445
# DWS         0.205678
# FG          0.219083
# PTS         0.235685
# Rk          0.238945
# Wins        0.248206
# Losses      0.263488
# W/L%        0.273570
# OBPM        0.339371
# OWS         0.341403
# PER         0.353164
# BPM         0.378084
# WS/48       0.389914
# VORP        0.394989
# WS          0.398826
# MVP Rank    0.410503
# Pts Won     0.690495
# Share       0.720222
# First       0.895434
# Won MVP     1.000000
# Name: Won MVP, dtype: float64

# %%
def plot_two_variables(df, title, var1, var1_order, var2, var2_order):
    matplotlib.pyplot.style.use('fivethirtyeight')
    fig, ax = matplotlib.pyplot.subplots()

    mvp = df[df['Won MVP'] == 1]
    non_mvp = df[df['Won MVP'] != 1]

    ax.scatter(mvp[var1], mvp[var2], label = 'MVP', marker = '^', s = 100)
    ax.scatter(non_mvp[var1], non_mvp[var2], label = 'Not MVP', alpha = .2)
    ax.set_xlim(ax.get_xlim()[::var1_order])
    ax.set_ylim(ax.get_ylim()[::var2_order])
    ax.legend(loc = 'best', prop = {'size': 12})
    ax.set_xlabel(var1, fontsize = 16)
    ax.set_ylabel(var2, fontsize = 16)

    fig.suptitle(title, weight = 'bold', size = 20)
    fig.text(x = -0.02, y = -0.08, s = '____________________________________________________', fontsize = 16, color = 'grey', horizontalalignment = 'left', alpha = .2)
    fig.text(x = -0.02, y = -0.16, s = 'https://crisbraatz.github.io', fontsize = 16, color = 'grey', horizontalalignment = 'left')

# %%
plot_two_variables(df_past, 'Player Win Share VS Team Overall Seed', 'Rk', -1, 'WS', 1)

# %%
df_past[(df_past['Won MVP'] == 1) & (df_past['Rk'] > 5)][['Player', 'Tm', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'FG%', '3P%', 'FT%', 'WS', 'WS/48', 'Season', 'Rk', 'Overall', 'W/L%']]
# Out:
#                   Player   Tm    MP   PTS   TRB   AST  STL  BLK    FG%    3P%  \
# 862         Moses Malone  HOU  42.0  31.1  14.7   1.8  0.9  1.5  0.519  0.000
# 2905      Michael Jordan  CHI  40.4  35.0   5.5   5.9  3.2  1.6  0.535  0.132
# 17260  Russell Westbrook  OKC  34.6  31.6  10.7  10.4  1.6  0.4  0.425  0.343
#
#          FT%    WS  WS/48  Season  Rk Overall      W/L%
# 862    0.762  15.4  0.218    1982   8   46-36  0.560976
# 2905   0.841  21.2  0.308    1988   8   50-32  0.609756
# 17260  0.845  13.1  0.224    2017  10   47-35  0.573171

# %%
plot_two_variables(df_past, 'Points Per Game VS Efficiency Rating', 'PTS', 1, 'PER', 1)

# %%
df_past[(df_past['Won MVP'] == 1) & (df_past['PTS'] <= 20)][['Player', 'Tm', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'FG%', '3P%', 'FT%', 'WS', 'WS/48', 'Season', 'Rk', 'Overall', 'W/L%']]
# Out:
#            Player   Tm    MP   PTS  TRB   AST  STL  BLK    FG%    3P%    FT%  \
# 10781  Steve Nash  PHO  34.3  15.5  3.3  11.5  1.0  0.1  0.502  0.431  0.887
# 11294  Steve Nash  PHO  35.4  18.8  4.2  10.5  0.8  0.2  0.512  0.439  0.921
#
#          WS  WS/48  Season  Rk Overall      W/L%
# 10781  10.9  0.203    2005   1   62-20  0.756098
# 11294  12.4  0.212    2006   4   54-28  0.658537

# %%
plot_two_variables(df_past, 'Team Overall Seed VS Player Value of Replacement', 'Rk', -1, 'VORP', 1)

# %%
def build_features(df_train, df_test):
    mms = MinMaxScaler()

    x_train_mms = mms.fit_transform(df_train[['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
                                              '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
                                              'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER', 'TS%', '3PAr', 'FTr',
                                              'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS',
                                              'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'Rk', 'Wins', 'Losses', 'W/L%', 'GS%', 'GP%']])
    x_test_mms = mms.transform(df_test[['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
                                        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
                                        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PER', 'TS%', '3PAr', 'FTr',
                                        'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS',
                                        'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'Rk', 'Wins', 'Losses', 'W/L%', 'GS%', 'GP%']])

    x_train = numpy.hstack([x_train_mms])
    x_test = numpy.hstack([x_test_mms])
    y_train = df_train['Won MVP'].values.reshape(-1, 1)
    y_test = df_test['Won MVP'].values.reshape(-1, 1)

    return x_train, y_train, x_test, y_test

# %%
model = LogisticRegression(solver = 'liblinear')

# %%
df_past_predicted = []
results_matrix = numpy.zeros(shape = (1, 2021 - 1980, 4, 2))
for season in range(1980, 2022):
    fold = season - 1980 - 1
    df_train = df_past[df_past.Season != season]
    df_test = df_past[df_past.Season == season]
    x_train, y_train, x_test, y_test = build_features(df_train, df_test)
    model.fit(x_train, y_train)

    df_train_rank = df_train.copy()
    df_train_rank['MVP Odds'] = model.predict_proba(x_train)[:, 1]
    df_train_rank['Predicted MVP Rank'] = df_train_rank.groupby('Season')['MVP Odds'].rank(ascending = False, method = 'dense')
    df_train_rank['Predicted MVP Winner'] = df_train_rank['Predicted MVP Rank']
    df_train_rank['Predicted MVP Winner'].loc[df_train_rank['Predicted MVP Winner'] != 1] = 0

    df_train_rank_won_mvp = df_train_rank['Won MVP']
    df_train_rank_predicted_mvp_winner = df_train_rank['Predicted MVP Winner']

    results_matrix[0, fold, 0, 0] = metrics.accuracy_score(df_train_rank_won_mvp, df_train_rank_predicted_mvp_winner)
    results_matrix[0, fold, 1, 0] = metrics.precision_score(df_train_rank_won_mvp, df_train_rank_predicted_mvp_winner)
    results_matrix[0, fold, 2, 0] = metrics.recall_score(df_train_rank_won_mvp, df_train_rank_predicted_mvp_winner)
    results_matrix[0, fold, 3, 0] = metrics.f1_score(df_train_rank_won_mvp, df_train_rank_predicted_mvp_winner)

    df_test_rank = df_test.copy()
    df_test_rank['MVP Odds'] = model.predict_proba(x_test)[:, 1]

    df_past_predicted.append(df_test_rank)

    df_test_rank['Predicted MVP Rank'] = df_test_rank.groupby('Season')['MVP Odds'].rank(ascending = False, method = 'dense')
    df_test_rank['Predicted MVP Winner'] = df_test_rank['Predicted MVP Rank']
    df_test_rank['Predicted MVP Winner'].loc[df_test_rank['Predicted MVP Winner'] != 1] = 0

    df_test_rank_won_mvp = df_test_rank['Won MVP']
    df_test_rank_predicted_mvp_winner = df_test_rank['Predicted MVP Winner']

    results_matrix[0, fold, 0, 1] = metrics.accuracy_score(df_test_rank_won_mvp, df_test_rank_predicted_mvp_winner)
    results_matrix[0, fold, 1, 1] = metrics.precision_score(df_test_rank_won_mvp, df_test_rank_predicted_mvp_winner)
    results_matrix[0, fold, 2, 1] = metrics.recall_score(df_test_rank_won_mvp, df_test_rank_predicted_mvp_winner)
    results_matrix[0, fold, 3, 1] = metrics.f1_score(df_test_rank_won_mvp, df_test_rank_predicted_mvp_winner)

# %%
print('Train')
print('Accuracy:', results_matrix[0, :, 0, 0].mean())
print('Precision:', results_matrix[0, :, 1, 0].mean())
print('Coverage:', results_matrix[0, :, 2, 0].mean())
print('F Measure:', results_matrix[0, :, 3, 0].mean())
print()
print('Test')
print('Accuracy:', results_matrix[0, :, 0, 1].mean())
print('Precision:', results_matrix[0, :, 1, 1].mean())
print('Coverage:', results_matrix[0, :, 2, 1].mean())
print('F Measure:', results_matrix[0, :, 3, 1].mean())
# Out:
# Train
# Accuracy: 0.9709542437330908
# Precision: 0.7656157049375372
# Coverage: 0.7656157049375372
# F Measure: 0.7656157049375374
#
# Test
# Accuracy: 0.9630212122152234
# Precision: 0.7073170731707317
# Coverage: 0.7073170731707317
# F Measure: 0.7073170731707317

# %%
df_past_predicted = pandas.concat(df_past_predicted)

# %%
df_past_predicted[(df_past_predicted['Won MVP'] == 1) & (df_past_predicted['Predicted MVP Winner'] != 1)][['Player', 'Tm', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'FG%', '3P%', 'FT%', 'WS', 'WS/48', 'Season', 'Rk', 'Overall', 'W/L%', 'Predicted MVP Rank']]
# Out:
#                   Player   Tm    MP   PTS   TRB   AST  STL  BLK    FG%    3P%  \
# 411        Julius Erving  PHI  35.0  24.6   8.0   4.4  2.1  1.8  0.521  0.222
# 862         Moses Malone  HOU  42.0  31.1  14.7   1.8  0.9  1.5  0.519  0.000
# 2905      Michael Jordan  CHI  40.4  35.0   5.5   5.9  3.2  1.6  0.535  0.132
# 4803     Charles Barkley  PHO  37.6  25.6  12.2   5.1  1.6  1.0  0.520  0.305
# 5501     Hakeem Olajuwon  HOU  41.0  27.3  11.9   3.6  1.6  3.7  0.528  0.421
# 6828         Karl Malone  UTA  36.6  27.4   9.9   4.5  1.4  0.6  0.550  0.000
# 8710       Allen Iverson  PHI  42.0  31.1   3.8   4.6  2.5  0.3  0.420  0.320
# 10781         Steve Nash  PHO  34.3  15.5   3.3  11.5  1.0  0.1  0.502  0.431
# 11294         Steve Nash  PHO  35.4  18.8   4.2  10.5  0.8  0.2  0.512  0.439
# 12040        Kobe Bryant  LAL  38.9  28.3   6.3   5.4  1.8  0.5  0.459  0.361
# 13945       Derrick Rose  CHI  37.4  25.0   4.1   7.7  1.0  0.6  0.445  0.332
# 17260  Russell Westbrook  OKC  34.6  31.6  10.7  10.4  1.6  0.4  0.425  0.343
#
#          FT%    WS  WS/48  Season  Rk Overall      W/L%  Predicted MVP Rank
# 411    0.787  13.8  0.231    1981   2   62-20  0.756098                 6.0
# 862    0.762  15.4  0.218    1982   8   46-36  0.560976                 4.0
# 2905   0.841  21.2  0.308    1988   8   50-32  0.609756                 2.0
# 4803   0.765  14.4  0.242    1993   1   62-20  0.756098                 2.0
# 5501   0.716  14.3  0.210    1994   2   58-24  0.707317                 3.0
# 6828   0.755  16.7  0.268    1997   2   64-18  0.780488                 2.0
# 8710   0.814  11.8  0.190    2001   3   56-26  0.682927                 4.0
# 10781  0.887  10.9  0.203    2005   1   62-20  0.756098                 7.0
# 11294  0.921  12.4  0.212    2006   4   54-28  0.658537                 8.0
# 12040  0.840  13.8  0.208    2008   3   57-25  0.695122                 6.0
# 13945  0.858  13.1  0.208    2011   1   62-20  0.756098                 2.0
# 17260  0.845  13.1  0.224    2017  10   47-35  0.573171                 3.0

# %%
df_past_predicted[(df_past_predicted['Won MVP'] != 1) & (df_past_predicted['Predicted MVP Winner'] == 1)][['Player', 'Tm', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'FG%', '3P%', 'FT%', 'WS', 'WS/48', 'Season', 'Rk', 'Overall', 'W/L%', 'MVP Rank']]
# Out:
#                     Player   Tm    MP   PTS   TRB   AST  STL  BLK    FG%  \
# 323    Kareem Abdul-Jabbar  LAL  37.2  26.2  10.3   3.4  0.7  2.9  0.574
# 673             Larry Bird  BOS  38.0  22.9  10.9   5.8  1.9  0.9  0.503
# 2761            Larry Bird  BOS  39.0  29.9   9.3   6.1  1.6  0.8  0.527
# 4964        Michael Jordan  CHI  39.3  32.6   6.7   5.5  2.8  0.8  0.495
# 5542        David Robinson  SAS  40.5  29.8  10.7   4.8  1.7  3.3  0.507
# 6786        Michael Jordan  CHI  37.9  29.6   5.9   4.3  1.7  0.5  0.486
# 8837      Shaquille O'Neal  LAL  39.5  28.7  12.7   3.7  0.6  2.8  0.572
# 10580           Tim Duncan  SAS  33.4  20.3  11.1   2.7  0.7  2.6  0.496
# 11301        Dirk Nowitzki  DAL  38.1  26.6   9.0   2.8  0.7  1.0  0.480
# 12339           Chris Paul  NOH  37.6  21.1   4.0  11.6  2.7  0.1  0.488
# 13790         LeBron James  MIA  38.8  26.7   7.5   7.0  1.6  0.6  0.510
# 16882         Kevin Durant  GSW  33.4  25.1   8.3   4.8  1.1  1.6  0.537
#
#          3P%    FT%    WS  WS/48  Season  Rk Overall      W/L%  MVP Rank
# 323    0.000  0.766  14.3  0.230    1981   5   54-28  0.658537       3.0
# 673    0.212  0.863  12.5  0.205    1982   1   63-19  0.768293       2.0
# 2761   0.414  0.916  15.0  0.243    1988   2   57-25  0.695122       2.0
# 4964   0.352  0.837  17.2  0.270    1993   3   57-25  0.695122       3.0
# 5542   0.345  0.749  20.0  0.296    1994   7   55-27  0.670732       2.0
# 6786   0.374  0.833  18.3  0.283    1997   1   69-13  0.841463       2.0
# 8837   0.000  0.513  14.9  0.245    2001   2   56-26  0.682927       3.0
# 10580  0.333  0.670  11.2  0.245    2005   3   59-23  0.719512       4.0
# 11301  0.406  0.901  17.7  0.275    2006   3   60-22  0.731707       3.0
# 12339  0.369  0.851  17.8  0.284    2008   4   56-26  0.682927       2.0
# 13790  0.330  0.759  15.6  0.244    2011   3   58-24  0.707317       3.0
# 16882  0.375  0.875  12.0  0.278    2017   1   67-15  0.817073       8.0

# %%
df_past_predicted[(df_past_predicted['Won MVP'] == 1) & (df_past_predicted['Predicted MVP Winner'] == 1)][['Player', 'Tm', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'FG%', '3P%', 'FT%', 'WS', 'WS/48', 'Season', 'Rk', 'Overall', 'W/L%']]
# Out:
#                       Player   Tm    MP   PTS   TRB   AST  STL  BLK    FG%  \
# 0        Kareem Abdul-Jabbar  LAL  38.3  24.8  10.8   4.5  1.0  3.4  0.604
# 1203            Moses Malone  PHI  37.5  24.5  15.3   1.3  1.1  2.0  0.501
# 1372              Larry Bird  BOS  38.3  24.2  10.1   6.6  1.8  0.9  0.492
# 1700              Larry Bird  BOS  39.5  28.7  10.5   6.6  1.6  1.2  0.522
# 2044              Larry Bird  BOS  38.0  25.8   9.8   6.8  2.0  0.6  0.496
# 2526           Magic Johnson  LAL  36.3  23.9   6.3  12.2  1.7  0.5  0.522
# 3282           Magic Johnson  LAL  37.5  22.5   7.9  12.8  1.8  0.3  0.509
# 3690           Magic Johnson  LAL  37.2  22.3   6.6  11.5  1.7  0.4  0.480
# 4127          Michael Jordan  CHI  37.0  31.5   6.0   5.5  2.7  1.0  0.539
# 4551          Michael Jordan  CHI  38.8  30.1   6.4   6.1  2.3  0.9  0.519
# 5966          David Robinson  SAS  38.0  27.6  10.8   2.9  1.7  3.2  0.530
# 6285          Michael Jordan  CHI  37.7  30.4   6.6   4.3  2.2  0.5  0.495
# 7293          Michael Jordan  CHI  38.8  28.7   5.8   3.5  1.7  0.5  0.465
# 7818             Karl Malone  UTA  37.4  23.8   9.4   4.1  1.3  0.6  0.493
# 8355        Shaquille O'Neal  LAL  40.0  29.7  13.6   3.8  0.5  3.0  0.574
# 9127              Tim Duncan  SAS  40.6  25.5  12.7   3.7  0.7  2.5  0.508
# 9584              Tim Duncan  SAS  39.3  23.3  12.9   3.9  0.7  2.9  0.513
# 10088          Kevin Garnett  MIN  39.4  24.2  13.9   5.0  1.5  2.2  0.499
# 11801          Dirk Nowitzki  DAL  36.2  24.6   8.9   3.4  0.7  0.8  0.502
# 12733           LeBron James  CLE  37.7  28.4   7.6   7.2  1.7  1.1  0.489
# 13262           LeBron James  CLE  39.0  29.7   7.3   8.6  1.6  1.0  0.503
# 14313           LeBron James  MIA  37.5  27.1   7.9   6.2  1.9  0.8  0.531
# 14811           LeBron James  MIA  37.9  26.8   8.0   7.3  1.7  0.9  0.565
# 15260           Kevin Durant  OKC  38.5  32.0   7.4   5.5  1.3  0.7  0.503
# 15771          Stephen Curry  GSW  32.7  23.8   4.3   7.7  2.0  0.2  0.487
# 16333          Stephen Curry  GSW  34.2  30.1   5.4   6.7  2.1  0.2  0.504
# 17507           James Harden  HOU  35.4  30.4   5.4   8.8  1.8  0.7  0.449
# 17916  Giannis Antetokounmpo  MIL  32.8  27.7  12.5   5.9  1.3  1.5  0.578
# 18532  Giannis Antetokounmpo  MIL  30.4  29.5  13.6   5.6  1.0  1.0  0.553
# 19415           Nikola Jokić  DEN  34.6  26.4  10.8   8.3  1.3  0.7  0.566
#
#          3P%    FT%    WS  WS/48  Season  Rk Overall      W/L%
# 0      0.000  0.765  14.8  0.227    1980   2   60-22  0.731707
# 1203   0.000  0.761  15.1  0.248    1983   1   65-17  0.792683
# 1372   0.247  0.888  13.6  0.215    1984   1   62-20  0.756098
# 1700   0.427  0.882  15.7  0.238    1985   1   63-19  0.768293
# 2044   0.423  0.896  15.8  0.244    1986   1   67-15  0.817073
# 2526   0.205  0.848  15.9  0.263    1987   1   65-17  0.792683
# 3282   0.314  0.911  16.1  0.267    1989   3   57-25  0.695122
# 3690   0.384  0.890  16.5  0.270    1990   1   63-19  0.768293
# 4127   0.312  0.851  20.3  0.321    1991   2   61-21  0.743902
# 4551   0.270  0.832  17.7  0.274    1992   1   67-15  0.817073
# 5966   0.300  0.774  17.5  0.273    1995   1   62-20  0.756098
# 6285   0.427  0.834  20.4  0.317    1996   1   72-10  0.878049
# 7293   0.238  0.784  15.8  0.238    1998   1   62-20  0.756098
# 7818   0.000  0.788   9.6  0.252    1999   2   37-13  0.740000
# 8355   0.000  0.524  18.6  0.283    2000   1   67-15  0.817073
# 9127   0.100  0.799  17.8  0.257    2002   3   58-24  0.707317
# 9584   0.273  0.710  16.5  0.248    2003   2   60-22  0.731707
# 10088  0.256  0.791  18.3  0.272    2004   2   58-24  0.707317
# 11801  0.416  0.904  16.3  0.278    2007   1   67-15  0.817073
# 12733  0.344  0.780  20.3  0.318    2009   1   66-16  0.804878
# 13262  0.333  0.767  18.5  0.299    2010   1   61-21  0.743902
# 14313  0.362  0.771  14.5  0.298    2012   4   46-20  0.696970
# 14811  0.406  0.753  19.3  0.322    2013   1   66-16  0.804878
# 15260  0.391  0.873  19.2  0.295    2014   2   59-23  0.719512
# 15771  0.443  0.914  15.7  0.288    2015   1   67-15  0.817073
# 16333  0.454  0.908  17.9  0.318    2016   1    73-9  0.890244
# 17507  0.367  0.858  15.4  0.289    2018   1   65-17  0.792683
# 17916  0.256  0.729  14.4  0.292    2019   1   60-22  0.731707
# 18532  0.304  0.633  11.1  0.279    2020   1   56-17  0.767123
# 19415  0.388  0.868  15.6  0.301    2021   5   47-25  0.652778

# %%
matplotlib.pyplot.title('Confusion Matrix - MVP Prediction')
seaborn.heatmap(confusion_matrix(df_past_predicted['Won MVP'], df_past_predicted['Predicted MVP Winner']), annot = True, fmt = '.2f', cmap = 'rocket_r')

matplotlib.pyplot.text(x = -0.02, y = 2.16, s = '__________________________________________', fontsize = 16, color = 'grey', horizontalalignment = 'left', alpha = .2)
matplotlib.pyplot.text(x = -0.02, y = 2.32, s = 'https://crisbraatz.github.io', fontsize = 16, color = 'grey', horizontalalignment = 'left')
matplotlib.pyplot.show()

# %%
df_current.Player.count()
# Out:
# 715

# %%
df_current = df_current[(df_current['GS%'] > 0.9) & (df_current['GP%'] > 0.7)]
df_current.Player.count()
# Out:
# 84

# %%
x_train, y_train, x_test, y_test = build_features(df_past, df_current)

model.fit(x_train, y_train)

df_current['MVP Odds'] = model.predict_proba(x_test)[:, 1]
df_current['Predicted MVP Rank'] = df_current.groupby('Season')['MVP Odds'].rank(ascending = False, method = 'dense')
df_current['Predicted MVP Winner'] = df_current['Predicted MVP Rank']
df_current['Predicted MVP Winner'].loc[df_current['Predicted MVP Winner'] != 1] = 0

# %%
df_current.sort_values(by = ['Predicted MVP Rank'], ascending = True)[['Player', 'Tm', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'FG%', '3P%', 'FT%', 'WS', 'WS/48', 'Season', 'Rk', 'Overall', 'W/L%', 'MVP Odds']].head(10)
# Out:
#                       Player   Tm    MP   PTS   TRB   AST  STL  BLK    FG%  \
# 20080           Nikola Jokić  DEN  33.5  27.1  13.8   7.9  1.5  0.9  0.583
# 19750  Giannis Antetokounmpo  MIL  32.9  29.9  11.6   5.8  1.1  1.4  0.553
# 19921            Joel Embiid  PHI  33.8  30.6  11.7   4.2  1.1  1.5  0.499
# 19896            Luka Dončić  DAL  35.4  28.4   9.1   8.7  1.2  0.6  0.457
# 20251             Chris Paul  PHO  32.9  14.7   4.4  10.8  1.9  0.3  0.493
# 19801           Devin Booker  PHO  34.5  26.8   5.0   4.8  1.1  0.4  0.466
# 19761          Deandre Ayton  PHO  29.5  17.2  10.2   1.4  0.7  0.7  0.634
# 19879          Stephen Curry  GSW  34.5  25.5   5.2   6.3  1.3  0.4  0.437
# 20359           Jayson Tatum  BOS  35.9  26.9   8.0   4.4  1.0  0.6  0.453
# 20448             Trae Young  ATL  34.9  28.4   3.7   9.7  0.9  0.1  0.460
#
#          3P%    FT%    WS  WS/48  Season  Rk Overall      W/L%  MVP Odds
# 20080  0.337  0.810  15.2  0.296    2022  10   48-34  0.585366  0.250606
# 19750  0.293  0.722  12.9  0.281    2022   7   51-31  0.621951  0.137287
# 19921  0.371  0.814  12.0  0.252    2022   8   51-31  0.621951  0.102941
# 19896  0.353  0.744   7.6  0.159    2022   5   52-30  0.634146  0.083718
# 20251  0.317  0.837   9.4  0.210    2022   1   64-18  0.780488  0.044631
# 19801  0.383  0.868   7.6  0.156    2022   1   64-18  0.780488  0.034172
# 19761  0.368  0.746   7.3  0.203    2022   1   64-18  0.780488  0.027319
# 19879  0.380  0.923   8.0  0.173    2022   3   53-29  0.646341  0.021088
# 20359  0.353  0.853   9.6  0.169    2022   6   51-31  0.621951  0.020861
# 20448  0.382  0.904  10.0  0.181    2022  16   43-39  0.524390  0.014043
